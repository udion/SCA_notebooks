# %%
using DataFrames

# %%
d = readtable("../_DATA_328p_attack-48-9D-B4-B3.csv",header = false)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
d[1,:]
# Out:
# 1×5003 DataFrames.DataFrame
# │ Row │ x1                                 │
# ├─────┼────────────────────────────────────┤
# │ 1   │ "E271F6FBB740DFF2C32E171255E100A5" │
#
# │ Row │ x2                                 │ x3     │ x4     │ x5      │
# ├─────┼────────────────────────────────────┼────────┼────────┼─────────┤
# │ 1   │ "9A3600D468E2BD80FBAEAF7F321F7090" │ 0.3252 │ 0.3128 │ 0.34208 │
#
# │ Row │ x6      │ x7      │ x8     │ x9      │ x10     │ x11     │ x12     │
# ├─────┼─────────┼─────────┼────────┼─────────┼─────────┼─────────┼─────────┤
# │ 1   │ 0.35928 │ 0.34816 │ 0.3556 │ 0.34048 │ 0.32248 │ 0.33952 │ 0.34968 │
#
# │ Row │ x13     │ x14     │ x15    │ x16     │ x17     │ x18     │ x19     │
# ├─────┼─────────┼─────────┼────────┼─────────┼─────────┼─────────┼─────────┤
# │ 1   │ 0.34256 │ 0.34624 │ 0.3424 │ 0.32416 │ 0.33096 │ 0.34432 │ 0.33776 │
#
# │ Row │ x20     │ x21     │ x22    │ x23    │ x24    │ x25     │ x26     │
# ...

# %%
writetable("../template_test.csv",d[:,1:end-1],header = false)

# %%
df = readtable("../template_test.csv",header = false)
# Out:
# WARNING: imported binding for df overwritten in module Main
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
df[1,:]
# Out:
# 1×5002 DataFrames.DataFrame
# │ Row │ x1                                 │
# ├─────┼────────────────────────────────────┤
# │ 1   │ "E271F6FBB740DFF2C32E171255E100A5" │
#
# │ Row │ x2                                 │ x3     │ x4     │ x5      │
# ├─────┼────────────────────────────────────┼────────┼────────┼─────────┤
# │ 1   │ "9A3600D468E2BD80FBAEAF7F321F7090" │ 0.3252 │ 0.3128 │ 0.34208 │
#
# │ Row │ x6      │ x7      │ x8     │ x9      │ x10     │ x11     │ x12     │
# ├─────┼─────────┼─────────┼────────┼─────────┼─────────┼─────────┼─────────┤
# │ 1   │ 0.35928 │ 0.34816 │ 0.3556 │ 0.34048 │ 0.32248 │ 0.33952 │ 0.34968 │
#
# │ Row │ x13     │ x14     │ x15    │ x16     │ x17     │ x18     │ x19     │
# ├─────┼─────────┼─────────┼────────┼─────────┼─────────┼─────────┼─────────┤
# │ 1   │ 0.34256 │ 0.34624 │ 0.3424 │ 0.32416 │ 0.33096 │ 0.34432 │ 0.33776 │
#
# │ Row │ x20     │ x21     │ x22    │ x23    │ x24    │ x25     │ x26     │
# ...
